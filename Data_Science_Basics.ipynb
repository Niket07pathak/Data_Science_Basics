# %%
import pandas as pd
import numpy as np

# colab-specific file access
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My Drive/Colab Notebooks
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks

# %% [markdown]
# The code below produces the data frames used in the examples:

# %%
heroes = pd.DataFrame(
    data={'color': ['red', 'green', 'black',
                    'blue', 'black', 'red'],
          'first_seen_on': ['a', 'a', 'f', 'a', 'a', 'f'],
          'first_season': [2, 1, 2, 3, 3, 1]},
    index=['flash', 'arrow', 'vibe',
           'atom', 'canary', 'firestorm']
)

identities = pd.DataFrame(
    data={'ego': ['barry allen', 'oliver queen', 'cisco ramon',
                  'ray palmer', 'sara lance',
                  'martin stein', 'ronnie raymond'],
          'alter-ego': ['flash', 'arrow', 'vibe', 'atom',
                        'canary', 'firestorm', 'firestorm']}
)

teams = pd.DataFrame(
    data={'team': ['flash', 'arrow', 'flash', 'legends',
                   'flash', 'legends', 'arrow'],
          'hero': ['flash', 'arrow', 'vibe', 'atom',
                   'killer frost', 'firestorm', 'speedy']})

# %% [markdown]
# ## Pandas and Wrangling

# %%
heroes
# Out:
#            color first_seen_on  first_season
# flash        red             a             2
# arrow      green             a             1
# vibe       black             f             2
# atom        blue             a             3
# canary     black             a             3
# firestorm    red             f             1

# %%
identities
# Out:
#               ego  alter-ego
# 0     barry allen      flash
# 1    oliver queen      arrow
# 2     cisco ramon       vibe
# 3      ray palmer       atom
# 4      sara lance     canary
# 5    martin stein  firestorm
# 6  ronnie raymond  firestorm

# %%
teams
# Out:
#       team          hero
# 0    flash         flash
# 1    arrow         arrow
# 2    flash          vibe
# 3  legends          atom
# 4    flash  killer frost
# 5  legends     firestorm
# 6    arrow        speedy

# %% [markdown]
# ### Slice and Dice
#
# #### Column selection by label

# %%
heroes.loc[:, 'color']
# Out:
# flash          red
# arrow        green
# vibe         black
# atom          blue
# canary       black
# firestorm      red
# Name: color, dtype: object

# %%
heroes.loc[:, ['color', 'first_season']]
# Out:
#            color  first_season
# flash        red             2
# arrow      green             1
# vibe       black             2
# atom        blue             3
# canary     black             3
# firestorm    red             1

# %%
heroes['first_seen_on']
# Out:
# flash        a
# arrow        a
# vibe         f
# atom         a
# canary       a
# firestorm    f
# Name: first_seen_on, dtype: object

# %% [markdown]
# #### Row Selection by Label

# %%
heroes.loc[['flash', 'vibe'], :]
# Out:
#        color first_seen_on  first_season
# flash    red             a             2
# vibe   black             f             2

# %%
heroes.loc[['flash', 'vibe']]
# Out:
#        color first_seen_on  first_season
# flash    red             a             2
# vibe   black             f             2

# %% [markdown]
# #### General Selection by Label

# %%
heroes.loc['flash':'atom', :'first_seen_on']
# Out:
#        color first_seen_on
# flash    red             a
# arrow  green             a
# vibe   black             f
# atom    blue             a

# %% [markdown]
# #### Selection by Integer Index

# %%
heroes.iloc[:4,:2]
# Out:
#        color first_seen_on
# flash    red             a
# arrow  green             a
# vibe   black             f
# atom    blue             a

# %% [markdown]
# ### Filtering with boolean arrays

# %%
heroes[(heroes['first_season']==3) & (heroes['first_seen_on']=='a')]
# Out:
#         color first_seen_on  first_season
# atom     blue             a             3
# canary  black             a             3

# %% [markdown]
# #### Problem Solving Strategy

# %%
heroes[heroes['first_season'].isin([1,3])]
# Out:
#            color first_seen_on  first_season
# arrow      green             a             1
# atom        blue             a             3
# canary     black             a             3
# firestorm    red             f             1

# %% [markdown]
# ### Counting Rows

# %%
heroes['color'].value_counts()
# Out:
# color
# red      2
# black    2
# green    1
# blue     1
# Name: count, dtype: int64

# %%
heroes.groupby(['color', 'first_season']).size()
# Out:
# color  first_season
# black  2               1
#        3               1
# blue   3               1
# green  1               1
# red    1               1
#        2               1
# dtype: int64

# %%
heroes.groupby(['color', 'first_season']).size().reset_index(name='count')
# Out:
#    color  first_season  count
# 0  black             2      1
# 1  black             3      1
# 2   blue             3      1
# 3  green             1      1
# 4    red             1      1
# 5    red             2      1

# %% [markdown]
# ### Joining Tables on One Column

# %%
heroes['hero'] = heroes.index
heroes
# Out:
#            color first_seen_on  first_season       hero
# flash        red             a             2      flash
# arrow      green             a             1      arrow
# vibe       black             f             2       vibe
# atom        blue             a             3       atom
# canary     black             a             3     canary
# firestorm    red             f             1  firestorm

# %% [markdown]
# #### Inner Join

# %%
pd.merge(heroes, teams, how='inner', on='hero')
# Out:
#    color first_seen_on  first_season       hero     team
# 0    red             a             2      flash    flash
# 1  green             a             1      arrow    arrow
# 2  black             f             2       vibe    flash
# 3   blue             a             3       atom  legends
# 4    red             f             1  firestorm  legends

# %% [markdown]
# #### Left and right join

# %%
pd.merge(heroes, teams, how='left', on='hero')
# Out:
#    color first_seen_on  first_season       hero     team
# 0    red             a             2      flash    flash
# 1  green             a             1      arrow    arrow
# 2  black             f             2       vibe    flash
# 3   blue             a             3       atom  legends
# 4  black             a             3     canary      NaN
# 5    red             f             1  firestorm  legends

# %% [markdown]
# #### Outer join

# %%
pd.merge(heroes, teams, how='outer', on='hero')
# Out:
#    color first_seen_on  first_season          hero     team
# 0    red             a           2.0         flash    flash
# 1  green             a           1.0         arrow    arrow
# 2  black             f           2.0          vibe    flash
# 3   blue             a           3.0          atom  legends
# 4  black             a           3.0        canary      NaN
# 5    red             f           1.0     firestorm  legends
# 6    NaN           NaN           NaN  killer frost    flash
# 7    NaN           NaN           NaN        speedy    arrow

# %% [markdown]
# #### More than one match?

# %%
pd.merge(heroes, identities, how='inner',
         left_on='hero', right_on='alter-ego')
# Out:
#    color first_seen_on  first_season       hero             ego  alter-ego
# 0    red             a             2      flash     barry allen      flash
# 1  green             a             1      arrow    oliver queen      arrow
# 2  black             f             2       vibe     cisco ramon       vibe
# 3   blue             a             3       atom      ray palmer       atom
# 4  black             a             3     canary      sara lance     canary
# 5    red             f             1  firestorm    martin stein  firestorm
# 6    red             f             1  firestorm  ronnie raymond  firestorm

# %% [markdown]
# ### Missing Values

# %%
x = np.nan
y = pd.merge(heroes, teams, how='outer', on='hero')['first_season']
y
# Out:
# 0    2.0
# 1    1.0
# 2    2.0
# 3    3.0
# 4    3.0
# 5    1.0
# 6    NaN
# 7    NaN
# Name: first_season, dtype: float64

# %%
pd.isnull(x)
# Out:
# True

# %%
y.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7     True
# Name: first_season, dtype: bool

# %%
pd.isnull(y)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7     True
# Name: first_season, dtype: bool

# %%
y.notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6    False
# 7    False
# Name: first_season, dtype: bool

# %%
y[y.notnull()]
# Out:
# 0    2.0
# 1    1.0
# 2    2.0
# 3    3.0
# 4    3.0
# 5    1.0
# Name: first_season, dtype: float64

# %% [markdown]
# "On-Time" flight data for all flights originating from SFO or OAK in January 2016. Information about the airports and airlines are contained in the comma-delimited files `airports.dat` and `airlines.dat`, respectively.  Both were sourced from https://openflights.org/data.php.

# %%
flights = pd.read_csv("flights.dat", dtype={'sched_dep_time': 'f8', 'sched_arr_time': 'f8', 'origin': 'string', 'destination': 'string'})
flights.head()
# Out:
#    year  month  day        date carrier tailnum  flight origin destination  \
# 0  2016      1    1  2016-01-01      AA  N3FLAA     208    SFO         MIA
# 1  2016      1    2  2016-01-02      AA  N3APAA     208    SFO         MIA
# 2  2016      1    3  2016-01-03      AA  N3DNAA     208    SFO         MIA
# 3  2016      1    4  2016-01-04      AA  N3FGAA     208    SFO         MIA
# 4  2016      1    5  2016-01-05      AA  N3KUAA     208    SFO         MIA
#
#    sched_dep_time  actual_dep_time  sched_arr_time  actual_arr_time
# 0           630.0            628.0          1458.0           1431.0
# 1           600.0            553.0          1428.0           1401.0
# 2           630.0            626.0          1458.0           1431.0
# 3           630.0            626.0          1458.0           1444.0
# 4           640.0            632.0          1458.0           1439.0

# %%
airports_cols = [
    'openflights_id',
    'name',
    'city',
    'country',
    'iata',
    'icao',
    'latitude',
    'longitude',
    'altitude',
    'tz',
    'dst',
    'tz_olson',
    'type',
    'airport_dsource'
]

airports = pd.read_csv("airports.dat", names=airports_cols, dtype={'iata': 'string', 'city':'string'})
airports.head(3)
# Out:
#    openflights_id         name         city           country iata  icao  \
# 0               1       Goroka       Goroka  Papua New Guinea  GKA  AYGA
# 1               2       Madang       Madang  Papua New Guinea  MAG  AYMD
# 2               3  Mount Hagen  Mount Hagen  Papua New Guinea  HGU  AYMH
#
#    latitude   longitude  altitude    tz dst              tz_olson  type  \
# 0 -6.081689  145.391881      5282  10.0   U  Pacific/Port_Moresby   NaN
# 1 -5.207083  145.788700        20  10.0   U  Pacific/Port_Moresby   NaN
# 2 -5.826789  144.295861      5388  10.0   U  Pacific/Port_Moresby   NaN
#
#    airport_dsource
# 0              NaN
# 1              NaN
# 2              NaN

# %%
airports.head(10)
# Out:
#    openflights_id                        name          city           country  \
# 0               1                      Goroka        Goroka  Papua New Guinea
# 1               2                      Madang        Madang  Papua New Guinea
# 2               3                 Mount Hagen   Mount Hagen  Papua New Guinea
# 3               4                      Nadzab        Nadzab  Papua New Guinea
# 4               5  Port Moresby Jacksons Intl  Port Moresby  Papua New Guinea
# 5               6                  Wewak Intl         Wewak  Papua New Guinea
# 6               7                  Narsarsuaq  Narssarssuaq         Greenland
# 7               8                        Nuuk      Godthaab         Greenland
# 8               9           Sondre Stromfjord   Sondrestrom         Greenland
# 9              10              Thule Air Base         Thule         Greenland
#
#   iata  icao   latitude   longitude  altitude    tz dst              tz_olson  \
# 0  GKA  AYGA  -6.081689  145.391881      5282  10.0   U  Pacific/Port_Moresby
# 1  MAG  AYMD  -5.207083  145.788700        20  10.0   U  Pacific/Port_Moresby
# 2  HGU  AYMH  -5.826789  144.295861      5388  10.0   U  Pacific/Port_Moresby
# 3  LAE  AYNZ  -6.569828  146.726242       239  10.0   U  Pacific/Port_Moresby
# 4  POM  AYPY  -9.443383  147.220050       146  10.0   U  Pacific/Port_Moresby
# 5  WWK  AYWK  -3.583828  143.669186        19  10.0   U  Pacific/Port_Moresby
# 6  UAK  BGBW  61.160517  -45.425978       112  -3.0   E       America/Godthab
# 7  GOH  BGGH  64.190922  -51.678064       283  -3.0   E       America/Godthab
# 8  SFJ  BGSF  67.016969  -50.689325       165  -3.0   E       America/Godthab
# 9  THU  BGTL  76.531203  -68.703161       251  -4.0   E         America/Thule
#
#    type  airport_dsource
# 0   NaN              NaN
# 1   NaN              NaN
# 2   NaN              NaN
# 3   NaN              NaN
# 4   NaN              NaN
# 5   NaN              NaN
# 6   NaN              NaN
# 7   NaN              NaN
# 8   NaN              NaN
# 9   NaN              NaN

# %%
def iata_to_city(iata_codes, airports):
    """
    Converts iata codes to city names.

    Args:
        iata_codes (string): series of iata codes given in string format.
        airports (Pandas Dataframe): dataframe containing information about airports.

    Returns:
        array (string): series of input dimension with names of cities.
    """
    iata = iata_codes.to_frame(name='iata')
    not_nan = iata[iata['iata'].notna()]
    city = pd.merge(not_nan, airports[['iata', 'city']], how='left', on='iata')
    ans = pd.merge(iata,city[['iata', 'city']], how='left', on='iata')
    return ans['city']

# %%
import unittest

class TestIataToCity(unittest.TestCase):
  def test_iata_to_city(self):
    ser = pd.Series(["ORD", "DFW", "SBN", np.nan], dtype='string')
    self.assertTrue(iata_to_city(ser, airports).equals(pd.Series(["Chicago", "Dallas-Fort Worth", "South Bend", np.nan], dtype='string')))

if __name__ == '__main__':
    unittest.main(argv=[''], exit=False)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.022s
#
# OK

# %%
def minutes_passed(time):
    """
    Converts military time to the number of minutes passed in the day

    Args:
        time (float64): series of time given in military format.
          Takes on values in 0.0-2359.0 due to float64 representation.

    Returns:
        array (float64): series of input dimension with number of minutes passed in the day

    Example: 1:03pm is converted to 783.0
    """

    hr=(time // 100)
    min=(time % 100)
    cond = (time >= 0) & (time < 2400) & (min<60)
    min_pass=(hr*60)+min

    return min_pass.where(cond,np.nan)


ser = pd.Series([1303,1200, 2400], dtype='float64')
minutes_passed(ser)
# Out:
# 0    783.0
# 1    720.0
# 2      NaN
# dtype: float64

# %%
import unittest

class TestMinutesPassed(unittest.TestCase):
  def test_minutes_passed(self):
    ser = pd.Series([743, 954, 2157, 300, 12, np.nan], dtype="float64")
    self.assertTrue(minutes_passed(ser).equals(pd.Series([463, 594, 1317, 180, 12, np.nan], dtype='float64')))

if __name__ == '__main__':
    unittest.main(argv=[''], exit=False)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.016s
#
# OK

# %%
def get_time_diff(x, y):
    """
    Calculates delay times y - x

    Args:
        x (float64): series of scheduled time given in military format.
          Takes on values in 0.0-2359.0 due to float64 representation.
        y (float64): series of same dimensions giving actual time

    Returns:
        array (float64): series of input dimension with delay time in minutes
    """

    return ((minutes_passed(y)-minutes_passed(x))*1)/1



sched = pd.Series([1303, 1210], dtype='float64')
actual = pd.Series([1304, 1215], dtype='float64')
get_time_diff(sched, actual)
# Out:
# 0    1.0
# 1    5.0
# dtype: float64

# %%
#delay_time = ... # Series object showing delay time for all flights
delay_time =  get_time_diff(flights['sched_arr_time'],flights['actual_arr_time'])
#on_time = ... # Dataframe showing flights that arrive on time
flights['delay_time']= delay_time
on_time = flights[flights['delay_time']<=10].iloc[:,:-1]
#delayed = ... # Dataframe showing flights that do NOT arrive on time
delayed = flights[flights['delay_time']>10].iloc[:,:-1]
print(delay_time)
print(on_time)
print(delayed)
# Out:
# 0         -27.0
# 1         -27.0
# 2         -27.0
# 3         -14.0
# 4         -19.0
#           ...
# 16856      59.0
# 16857      68.0
# 16858   -1254.0
# 16859   -1264.0
# 16860     130.0
# Length: 16861, dtype: float64
#        year  month  day        date carrier tailnum  flight origin  \
# 0      2016      1    1  2016-01-01      AA  N3FLAA     208    SFO
# 1      2016      1    2  2016-01-02      AA  N3APAA     208    SFO
# 2      2016      1    3  2016-01-03      AA  N3DNAA     208    SFO
# 3      2016      1    4  2016-01-04      AA  N3FGAA     208    SFO
# 4      2016      1    5  2016-01-05      AA  N3KUAA     208    SFO
# ...     ...    ...  ...         ...     ...     ...     ...    ...
# 16852  2016      1   11  2016-01-11      F9  N227FR     660    SFO
# 16854  2016      1   20  2016-01-20      F9  N952FR     756    SFO
# 16855  2016      1    3  2016-01-03      F9  N208FR    1124    SFO
# 16858  2016      1    3  2016-01-03      F9  N910FR     662    SFO
# 16859  2016      1    3  2016-01-03      F9  N921FR     668    SFO
#
#       destination  sched_dep_time  actual_dep_time  sched_arr_time  \
# 0             MIA           630.0            628.0          1458.0
# 1             MIA           600.0            553.0          1428.0
# 2             MIA           630.0            626.0          1458.0
# 3             MIA           630.0            626.0          1458.0
# 4             MIA           640.0            632.0          1458.0
# ...           ...             ...              ...             ...
# 16852         DEN           600.0            553.0           933.0
# 16854         PHX          1555.0           1611.0          1900.0
# 16855         LAS          2145.0           2145.0          2310.0
# 16858         DEN          1740.0           2056.0          2116.0
# 16859         DEN          2000.0           2249.0          2330.0
#
#        actual_arr_time
# 0               1431.0
# 1               1401.0
# 2               1431.0
# 3               1444.0
# 4               1439.0
# ...                ...
# 16852            935.0
# 16854           1906.0
# 16855           2320.0
# 16858             22.0
# 16859            226.0
#
# [12005 rows x 13 columns]
#        year  month  day        date carrier tailnum  flight origin  \
# 11     2016      1   12  2016-01-12      AA  N3LXAA     208    SFO
# 12     2016      1   13  2016-01-13      AA  N3JVAA     208    SFO
# 14     2016      1   15  2016-01-15      AA  N3GUAA     208    SFO
# 15     2016      1   16  2016-01-16      AA  N3GAAA     208    SFO
# 19     2016      1   20  2016-01-20      AA  N3BBAA     208    SFO
# ...     ...    ...  ...         ...     ...     ...     ...    ...
# 16846  2016      1   10  2016-01-10      F9  N211FR     654    SFO
# 16853  2016      1   11  2016-01-11      F9  N230FR    1248    SFO
# 16856  2016      1    3  2016-01-03      F9  N211FR    1248    SFO
# 16857  2016      1    3  2016-01-03      F9  N232FR     654    SFO
# 16860  2016      1    3  2016-01-03      F9  N921FR    1360    SFO
#
#       destination  sched_dep_time  actual_dep_time  sched_arr_time  \
# 11            MIA           640.0            645.0          1458.0
# 12            MIA           640.0            640.0          1458.0
# 14            MIA           640.0            638.0          1458.0
# 15            MIA           640.0            723.0          1458.0
# 19            MIA           640.0            726.0          1458.0
# ...           ...             ...              ...             ...
# 16846         DEN          1055.0           1236.0          1427.0
# 16853         ORD          1310.0           1508.0          1935.0
# 16856         ORD          1245.0           1341.0          1900.0
# 16857         DEN          1130.0           1244.0          1505.0
# 16860         PHX          1430.0           1647.0          1727.0
#
#        actual_arr_time
# 11              1530.0
# 12              1527.0
# 14              1728.0
# 15              1534.0
# 19              1532.0
# ...                ...
# 16846           1602.0
# 16853           2129.0
# 16856           1959.0
# 16857           1613.0
# 16860           1937.0
#
# [4354 rows x 13 columns]

# %%
sfo_oak = on_time[on_time['origin'].isin(['SFO', 'OAK'])]
ser=sfo_oak['destination'][:]
cities=iata_to_city(ser,airports)

#on_time_airports = ... # first get a Dataframe showing airports where on-time flights arrive
on_time_airports = airports[airports['city'].isin(cities)]
print(on_time_airports)
#on_time_destinations = ... # then get the unique and sorted destination cities
on_time_destinations= on_time_airports['city'].drop_duplicates().sort_values()
print(on_time_destinations)
# Out:
#       openflights_id                               name             city  \
# 1065            1085                        Saint Louis        St. Louis
# 1695            6880          Montrose Regional Airport      Montrose CO
# 1838            6877            North Las Vegas Airport        Las Vegas
# 2584            2654                      Maria Dolores      Los Angeles
# 2694            2766               Santa Ana Del Yacuma        Santa Ana
# ...              ...                                ...              ...
# 8032            9467                    Port Everglades  Fort Lauderdale
# 8068            9503             Holmesburg Jct Station     Philadelphia
# 8071            9506           B Street Cruise Terminal        San Diego
# 8077            9512                    Port of Seattle          Seattle
# 8106            9541  San Diego Old Town Transit Center        San Diego
#
#             country  iata  icao   latitude   longitude  altitude   tz dst  \
# 1065        Senegal   XLS  GOSS  16.050761  -16.463172         9  0.0   N
# 1695  United States   MTJ  KMTJ  38.509794 -107.894242      5759 -7.0   A
# 1838  United States   VGT    \N  36.210694 -115.194444      2205 -8.0   U
# 2584          Chile   LSQ  SCGE -37.401731  -72.425444       374 -4.0   S
# 2694        Bolivia  <NA>  SLSA -13.762208  -65.435158       472 -4.0   U
# ...             ...   ...   ...        ...         ...       ...  ...  ..
# 8032  United States  <NA>  FTLD  26.087679  -80.115942         0 -5.0   A
# 8068  United States  <NA>  HOLM  40.032679  -75.023718        39 -5.0   U
# 8071  United States  <NA>  SANB  32.716861 -117.174296         0 -8.0   A
# 8077  United States  <NA>  PSEA  47.609178 -122.350605         0 -8.0   A
# 8106  United States   OLT    \N  32.755200 -117.199500         0 -8.0   A
#
#                  tz_olson  type  airport_dsource
# 1065         Africa/Dakar   NaN              NaN
# 1695       America/Denver   NaN              NaN
# 1838  America/Los_Angeles   NaN              NaN
# 2584     America/Santiago   NaN              NaN
# 2694       America/La_Paz   NaN              NaN
# ...                   ...   ...              ...
# 8032     America/New_York   NaN              NaN
# 8068     America/New_York   NaN              NaN
# 8071  America/Los_Angeles   NaN              NaN
# 8077  America/Los_Angeles   NaN              NaN
# 8106  America/Los_Angeles   NaN              NaN
#
# [225 rows x 14 columns]
# 3911    Albuquerque
# 3339      Anchorage
# 4271      Arcata CA
# 5576          Aspen
# 3583        Atlanta
#            ...
# 3478        Seattle
# 3368        Spokane
# 1065      St. Louis
# 3463         Tucson
# 3421     Washington
# Name: city, Length: 76, dtype: string

# %%
sfo_oak = delayed[delayed['origin'].isin(['SFO', 'OAK'])]
ser=sfo_oak['destination'][:]
cities=iata_to_city(ser,airports)
#late_airports = ... # first get a Dataframe showing airports where late flights arrive
late_airports = airports[airports['city'].isin(cities)]
print(late_airports)
#late_destinations = ... # then get the unique and sorted destination cities
late_destinations= on_time_airports['city'].drop_duplicates().sort_values()
print(late_destinations)
# Out:
#       openflights_id                               name             city  \
# 1065            1085                        Saint Louis        St. Louis
# 1695            6880          Montrose Regional Airport      Montrose CO
# 1838            6877            North Las Vegas Airport        Las Vegas
# 2584            2654                      Maria Dolores      Los Angeles
# 2694            2766               Santa Ana Del Yacuma        Santa Ana
# ...              ...                                ...              ...
# 8032            9467                    Port Everglades  Fort Lauderdale
# 8068            9503             Holmesburg Jct Station     Philadelphia
# 8071            9506           B Street Cruise Terminal        San Diego
# 8077            9512                    Port of Seattle          Seattle
# 8106            9541  San Diego Old Town Transit Center        San Diego
#
#             country  iata  icao   latitude   longitude  altitude   tz dst  \
# 1065        Senegal   XLS  GOSS  16.050761  -16.463172         9  0.0   N
# 1695  United States   MTJ  KMTJ  38.509794 -107.894242      5759 -7.0   A
# 1838  United States   VGT    \N  36.210694 -115.194444      2205 -8.0   U
# 2584          Chile   LSQ  SCGE -37.401731  -72.425444       374 -4.0   S
# 2694        Bolivia  <NA>  SLSA -13.762208  -65.435158       472 -4.0   U
# ...             ...   ...   ...        ...         ...       ...  ...  ..
# 8032  United States  <NA>  FTLD  26.087679  -80.115942         0 -5.0   A
# 8068  United States  <NA>  HOLM  40.032679  -75.023718        39 -5.0   U
# 8071  United States  <NA>  SANB  32.716861 -117.174296         0 -8.0   A
# 8077  United States  <NA>  PSEA  47.609178 -122.350605         0 -8.0   A
# 8106  United States   OLT    \N  32.755200 -117.199500         0 -8.0   A
#
#                  tz_olson  type  airport_dsource
# 1065         Africa/Dakar   NaN              NaN
# 1695       America/Denver   NaN              NaN
# 1838  America/Los_Angeles   NaN              NaN
# 2584     America/Santiago   NaN              NaN
# 2694       America/La_Paz   NaN              NaN
# ...                   ...   ...              ...
# 8032     America/New_York   NaN              NaN
# 8068     America/New_York   NaN              NaN
# 8071  America/Los_Angeles   NaN              NaN
# 8077  America/Los_Angeles   NaN              NaN
# 8106  America/Los_Angeles   NaN              NaN
#
# [222 rows x 14 columns]
# 3911    Albuquerque
# 3339      Anchorage
# 4271      Arcata CA
# 5576          Aspen
# 3583        Atlanta
#            ...
# 3478        Seattle
# 3368        Spokane
# 1065      St. Louis
# 3463         Tucson
# 3421     Washington
# Name: city, Length: 76, dtype: string

# %% [markdown]
# ###Web scraping and data collection
#
#
# * Using HTTP to fetch the content of a website
# * HTTP Requests (and lifecycle)
# * RESTful APIs
#     * Authentication (OAuth)
#     * Pagination
#     * Rate limiting
# * JSON vs. HTML
# * HTML traversal (CSS selectors)
#
#
# [link text](https://)

# %%
import io, time, json
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## Authentication and working with APIs

# %%
def retrieve_html(url):
    """
    Return the raw HTML at the specified URL.

    Args:
        url (string):

    Returns:
        status_code (integer):
        raw_html (string): the raw HTML content of the response, properly encoded according to the HTTP headers.
    """

    response=requests.get(url)
    return (response.status_code,response.text)

# %%
youtube_article = retrieve_html('https://apnews.com/article/north-america-technology-business-journalism-media-a3b9b5a518f247b8a2ebbf4fb5c2d9ed')
print(youtube_article)
# Out:
# (200, '\n    <!DOCTYPE html>\n<html class="StoryPage" lang="en" data-header-hasleaderboard="true" data-named-page-type="Article"  data-leaderboard-is-fixed="true" data-hasZephr="true"data-lead="medium">\n    \n    <head>\n    \n        \n\n<script type="text/javascript" src="https://cdn.cookielaw.org/consent/a71f6440-204e-44d0-b5f6-af7a3c22073f/OtAutoBlock.js"></script>\n\n    \n    <meta charset="UTF-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1">\n\n    <meta property="og:title" content="YouTube aims to crack down on fake news, support journalism">\n\n    <meta property="og:url" content="https://apnews.com/article/a3b9b5a518f247b8a2ebbf4fb5c2d9ed">\n\n    <meta name="thumbnail" content="https://dims.apnews.com/dims4/default/47261ea/2147483647/strip/true/crop/3000x1688+0+219/resize/1440x810!/quality/90/?url=https%3A%2F%2Fstorage.googleapis.com%2Fafs-prod%2Fmedia%2Fmedia%3A92f6087df7c14acd88ddb53ed6f2dd85%2F3000.jpeg">\n    <meta property="og:image" content="https://dims.apnews.com/dims4/default/47261ea/2147483647/strip/true/crop/3000x1688+0+219/resize/1440x810!/quality/90/?url=https%3A%2F%2Fstorage.googleapis.com%2Fafs-prod%2Fmedia%2Fmedia%3A92f6087df7c14acd88ddb53ed6f2dd85%2F3000.jpeg">\n\n    \n    <meta property="og:image:url" content="https://dims.apnews.com/dims4/default/47261ea/2147483647/strip/true/crop/3000x1688+0+219/resize/1440x810!/quality/90/?url=https%3A%2F%2Fstorage.googleapis.com%2Fafs-prod%2Fmedia%2Fmedia%3A92f6087df7c14acd88ddb53ed6f2dd85%2F3000.jpeg">\n    \n    <meta property="og:image:width" content="1440">\n    <meta property="og:image:height" content="810">\n    <meta property="og:image:type" content="image/jpeg">\n    \n    <meta property="og:image:alt" content="\n              This image provided by Google shows a page of Local news in the free YouTube app for TV screens. Google&#x27;s YouTube says it is taking several steps to ensure the veracity of news on its service by cracking down on misinformation and supporting news organizations. The company said Monday, July 9, 2018, it will make &quot;authoritative&quot; news sources more prominent, especially in the wake of breaking news events when misinformation can spread quickly. (Google via AP)\n            ">\n    \n\n\n    <meta property="og:description" content="NEW YORK (AP) — Google&#x27;s YouTube says it is taking several steps to ensure the veracity of news on its service by cracking down on misinformation and supporting news organizations.">\n\n    <meta property="og:site_name" content="AP News">\n\n\n\n    <meta property="og:type" content="article">\n\n    <meta property="article:published_time" content="2018-07-09T23:15:58">\n\n    <meta property="article:modified_time" content="2021-04-28T21:07:44.442">\n\n    <meta property="article:tag" content="Fake news">\n\n    <meta property="article:tag" content="Media">\n\n    <meta property="article:tag" content="Journalism">\n\n    <meta property="article:tag" content="North America">\n\n    \n    <meta name="twitter:card" content="summary_large_image">\n    \n    \n    \n    \n    <meta name="twitter:description" content="NEW YORK (AP) — Google&#x27;s YouTube says it is taking several steps to ensure the veracity of news on its service by cracking down on misinformation and supporting news organizations."/>\n    \n    \n    <meta name="twitter:image" content="https://dims.apnews.com/dims4/default/47261ea/2147483647/strip/true/crop/3000x1688+0+219/resize/1440x810!/quality/90/?url=https%3A%2F%2Fstorage.googleapis.com%2Fafs-prod%2Fmedia%2Fmedia%3A92f6087df7c14acd88ddb53ed6f2dd85%2F3000.jpeg"/>\n\n    <meta name="twitter:image:alt" content="\n              This image provided by Google shows a page of Local news in the free YouTube app for TV screens. Google&#x27;s YouTube says it is taking several steps to ensure the veracity of news on its service by cracking down on misinformation and supporting news organizations. The company said Monday, July 9, 2018 ...

# %% [markdown]
# ## Yelp API Access
# ###Authenticated HTTP Request with the Yelp API

# %%
with open('/content/yelp_api_key.txt', 'r') as f:
    api_key = f.read().replace('\n','')
    print(api_key)
# Out:
# ZwaDNPmJ63AwlQjgp7a6du0T0pysCKH6eXmD_OQlt87zKAkOzpmR8_7oZXQlfWOYj674cUQJAutz-i8JzqdOEVx5TCMm2Zh5XMkNXjX9Q5e7fdcnzubNrRUbeGjrZnYx

# %%
def read_api_key(filepath):
    """
    Read the Yelp API Key from file.

    Args:
        filepath (string): File containing API Key
    Returns:
        api_key (string): The API Key
    """

    with open(filepath, 'r') as f:
        return f.read().replace('\n','')

# %%
read_api_key('/content/yelp_api_key.txt')
# Out:
# 'ZwaDNPmJ63AwlQjgp7a6du0T0pysCKH6eXmD_OQlt87zKAkOzpmR8_7oZXQlfWOYj674cUQJAutz-i8JzqdOEVx5TCMm2Zh5XMkNXjX9Q5e7fdcnzubNrRUbeGjrZnYx '

# %% [markdown]
# Using the Yelp API, fill in the following function stub to make an authenticated request to the [search](https://docs.developer.yelp.com/reference/v3_business_search) endpoint. Remember Yelp allows you to pass the API Key via a special HTTP Header: `Authorization: Bearer <API_KEY>`. Check out the [docs](https://docs.developer.yelp.com/docs/fusion-authentication) for more information.

# %%
def location_search_params(api_key, location, **kwargs):
    """
    Construct url, headers and url_params. Reference API docs (link above) to use the arguments
    """
    url = 'https://api.yelp.com/v3/businesses/search'
    headers =  {
        'Authorization': 'Bearer ' + api_key
    }
    url_params = {
        'location': location.replace(' ','+')
    }
    url_params.update(kwargs)

    return url, headers, url_params

# %%
api_key = "test_api_key_xyz"
location = "Chicago"
url, headers, url_params = location_search_params(api_key, location, offset=0, limit=50)
url, headers, url_params
# Out:
# ('https://api.yelp.com/v3/businesses/search',
#  {'Authorization': 'Bearer test_api_key_xyz'},
#  {'location': 'Chicago', 'offset': 0, 'limit': 50})

# %%
def api_get_request(url, headers, url_params):
    """
    Send a HTTP GET request and return a json response

    Args:
        url (string): API endpoint url
        headers (dict): A python dictionary containing HTTP headers including Authentication to be sent
        url_params (dict): The parameters (required and optional) supported by endpoint

    Returns:
        results (json): response as json
    """
    http_method = 'GET'
    response = requests.request(http_method, url, headers=headers, params=url_params)

    return response.json()


def yelp_search(api_key, location, offset=0):
    """
    Make an authenticated request to the Yelp API.

    Args:
        api_key (string): Your Yelp API Key for Authentication
        location (string): Business Location
        offset (int): param for pagination

    Returns:
        total (integer): total number of businesses on Yelp corresponding to the location
        businesses (list): list of dicts representing each business
    """
    url, headers, url_params = location_search_params(api_key, location, offset=0)
    response_json = api_get_request(url, headers, url_params)
    return response_json["total"], list(response_json["businesses"])

api_key = read_api_key('/content/yelp_api_key.txt')
num_records, data = yelp_search(api_key, 'Chicago')
print(num_records)

print(len(data))
print(list(map(lambda x: x['name'], data)))
# Out:
# 11100
# 20
# ['Girl & The Goat', 'Au Cheval', 'The Purple Pig', 'Wildberry Pancakes and Cafe', 'Cafe Ba-Ba-Reeba!', 'Aba', 'etta - Bucktown', 'Penumbra', 'The Dearborn', 'Rose Mary', 'Boka', 'The Gage', 'Alinea', 'S.K.Y.', "Joe's Seafood, Prime Steak & Stone Crab", 'Kasama', "Bavette's Bar & Boeuf", 'KAI ZAN', "Cindy's Rooftop", 'Il Porcellino']

# %% [markdown]
# ## Parameterization and Pagination
#
#
#
#
# ###All of the restaurants in Chicago on Yelp

# %%
def paginated_restaurant_search_requests(api_key, location, total):
    """
    Returns a list of tuples (url, headers, url_params) for paginated search of all restaurants
    Args:
        api_key (string): Your Yelp API Key for Authentication
        location (string): Business Location
        total (int): Total number of items to be fetched
    Returns:
        results (list): list of tuple (url, headers, url_params)
    """

    url, headers, url_params = location_search_params(api_key,location)
    offset = 0
    limit = 10
    res = []
    if total % limit == 0:
      num_res= int(total/limit)
    else:
      num_res= int(total//limit)+1

    for offset in range(0, num_res * limit, limit):
        url_params = {
            'location': location,
            'offset': offset,
            'limit': limit,
            'categories': 'restaurants'
        }
        res.append((url, headers, url_params))
        time.sleep(0.2)

    return  res

api_key = "test_api_key_xyz"
location = "Chicago"
all_restaurants_requests = paginated_restaurant_search_requests(api_key, location, 15)
all_restaurants_requests
# Out:
# [('https://api.yelp.com/v3/businesses/search',
#   {'Authorization': 'Bearer test_api_key_xyz'},
#   {'location': 'Chicago',
#    'offset': 0,
#    'limit': 10,
#    'categories': 'restaurants'}),
#  ('https://api.yelp.com/v3/businesses/search',
#   {'Authorization': 'Bearer test_api_key_xyz'},
#   {'location': 'Chicago',
#    'offset': 10,
#    'limit': 10,
#    'categories': 'restaurants'})]

# %%
def all_restaurants(api_key, location):
    """
    Construct the pagination requests for ALL the restaurants on Yelp for a given location.

    Args:
        api_key (string): Your Yelp API Key for Authentication
        location (string): Business Location

    Returns:
        results (list): list of dicts representing each restaurant
    """
    url, headers, url_params = location_search_params(api_key, location,limit=10,offset=0,categories='restaurants')
    response_json = api_get_request(url, headers, url_params)
    total_items = response_json["total"]
    all_restaurants_request = paginated_restaurant_search_requests(api_key, location, total_items)

    res_data = []
    for req_url, req_headers, req_url_params in all_restaurants_request:
      response_res = api_get_request(req_url, req_headers, req_url_params)
      res_data += response_res["businesses"]
      time.sleep(0.2)

    return res_data

# %%
api_key = read_api_key('/content/yelp_api_key.txt')
data = all_restaurants(api_key, 'Greektown, Chicago, IL')
print(len(data))

print(list(map(lambda x:x['name'], data)))
# Out:
# 116
# ['Greek Islands Restaurant', 'Girl & The Goat', 'Athena Greek Restaurant', 'Monteverde', 'Meli Cafe & Juice Bar', 'Rye Deli & Drink', 'Xi’an Cuisine', 'Green Street Smoked Meats', 'CityBird', 'Trivoli Tavern', "Formento's", 'SUSHI DOKKU Japanese Restaurant', 'El Che Steakhouse & Bar', 'Viaggio Ristorante & Lounge', 'The Allis', 'Zeus Restaurant', 'Tamashii Ramen', "Nancy's Pizza Chicago - West Loop", 'Sepia', 'Green Street Local', 'Suenos x Soho House', 'High Five Ramen', 'Primos Chicago Pizza', 'Spectrum Bar and Grill', '9 Muses', 'Booze Box', 'Omakase Yume', 'J.P. Graziano Grocery', 'Lola’s Restaurant & Bar', 'TenGoku Aburiya', 'Mr Greek Gyros', 'Ciao! Cafe & Wine Lounge', "Nando's Peri-Peri", 'Jubilee Juice & Grill', 'Taco Lulú', 'Swadesi Cafe', "Giordano's", "Lou Mitchell's", 'SGD Dubu So Gong Dong Tofu & Korean BBQ', "Philly's Best", 'Parlor Pizza Bar', "Nonna's Pizza & Sandwiches", 'Slightly Toasted', 'Stelios Bottles & Bites', 'Taco Burrito King - Greektown', 'Tamu', 'Blaze Pizza', 'Yolk West Loop', 'Blackwood BBQ', 'Sushi Pink', 'Morgan Street Cafe', 'Xi’an Cuisine - West Loop', 'Tacombi', 'Beggars Pizza', "Wok N' Bao", 'Asadito', 'Dylans Tavern & Grill', "Jet's Pizza", 'K-Kitchen', 'Pockets', 'I Dream of Falafel', 'Naf Naf Grill', 'Metro Spice Mart', 'Subway', "Sang's Kitchen", "Jimmy John's", 'Klay Oven Kitchen', 'Izakaya Yume', 'Five Guys', 'Oki Sushi', 'Crepe & Bean', 'Red Star Bar', 'Chipotle Mexican Grill', "Domino's Pizza", 'Potbelly Sandwich Shop', 'Potbelly Sandwich Shop', "Jimmy John's", 'Great Steak', 'Taco Bell Cantina', 'Hunan House', "Harold's Chicken On Clinton", 'Bonyeon', 'Čálli', 'Dosbros Fresh Mexican Grill', "Sam's Crispy Chicken - West Loop", 'Market Creations - Adams', 'Burger King', "Byrd's Hot Chicken", 'Barrel Cafe', 'Green Room', 'Chopstix Express', 'this little goat kitchen', 'Toreore', 'Kikka Sushi', 'Market Cocina', 'Start Sampling', 'G L I Food Service', 'Pizza Villa & Cafe', 'Cafe Italo', "Uncle Tommy's BBQ", 'Marche', 'Burger King', 'In a Bun', 'Subway', 'EL FOCO TACOS', 'West Loop Sandwich', 'Chopped Salad Bar', 'Kabob City', 'Wing Run', 'Chi Town Sandwich', 'Le Peep Grill', 'Spaketeria', "Popeye's Famous Fried Chicken", 'Halsted Street Deli', 'Flik International', 'Sweet Corner']

# %% [markdown]
# ##Parsing the API Responses and Extract the URLs

# %%
data
# Out:
# [{'id': '_UJ3KqtHIHjExbAg-iIGUA',
#   'alias': 'greek-islands-restaurant-chicago',
#   'name': 'Greek Islands Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/E9eB7tElrGp8h4IhsS6JHg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/greek-islands-restaurant-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 2184,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.87896, 'longitude': -87.64763},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '200 S Halsted St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60661',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['200 S Halsted St', 'Chicago, IL 60661']},
#   'phone': '+13127829855',
#   'display_phone': '(312) 782-9855',
#   'distance': 58.284179728484794,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1100',
#       'end': '2100',
#       'day': 1},
#      {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 2},
#      {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 3},
#      {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 4},
#      {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 5},
#      {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': '',
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'qjnpkS8yZO8xcyEIy5OU9A',
#   'alias': 'girl-and-the-goat-chicago',
#   'name': 'Girl & The Goat',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ya6gjD4BPlxe7AKMj_5WsA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/girl-and-the-goat-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 10243,
#   'categories': [{'alias': 'newamerican', 'title': 'New American'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'bakeries', 'title': 'Bakeries'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 41.8841464, 'longitude': -87.6480959},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '809 W Randolph',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['809 W Randolph', 'Chicago, IL 60607']},
#   'phone': '+13124926262',
#   'display_phone': '(312) 492-6262',
#   'distance': 533.3694715114,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1630',
#       'end': '2300',
#       'day': 0},
#      {'is_overnight': False, 'start': '1630', 'end': '2300', 'day': 1},
#      {'is_overnight': False, 'start': '1630', 'end': '2300', 'day': 2},
#      {'is_overnight': False, 'start': '1630', 'end': '2300', 'day': 3},
#      {'is_overnight': False, 'start': '1630', 'end': '2300', 'day': 4},
#      {'is_overnight': False, 'start': '1630', 'end': '2300', 'day': 5},
#      {'is_overnight': False, 'start': '1630', 'end': '2300', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': 'https://www.girlandthegoat.com/chicago/menu',
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'nHpdKk4hYQVbYyT-CeD7_Q',
#   'alias': 'athena-greek-restaurant-chicago',
#   'name': 'Athena Greek Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/q05MqvWu1FBOSfCV4VJ-XQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/athena-greek-restaurant-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 1045,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 41.878708210046526,
#    'longitude': -87.64739682037741},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '212 S Halsted St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60661',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['212 S Halsted St', 'Chicago, IL 60661']},
#   'phone': '+13126550000',
#   'display_phone': '(312) 655-0000',
#   'distance': 76.54559739982774,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1100',
#       'end': '2100',
#       'day': 0},
#      {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 1},
#      {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 2},
#      {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 3},
#      {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 4},
#      {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 5},
#      {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': 'https://www.athenachicago.com/menus',
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'o0DaPvRb4IWH7hUWVCnoGw',
#   'alias': 'monteverde-chicago',
#   'name': 'Monteverde',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tszIjTXr0NVKJEmumJ_xZg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/monteverde-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 1311,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.88191, 'longitude': -87.65302},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '1020 W Madison St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1020 W Madison St', 'Chicago, IL 60607']},
#   'phone': '+13128883041',
#   'display_phone': '(312) 888-3041',
#   'distance': 564.2942749499658,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1100',
#       'end': '2130',
#       'day': 1},
#      {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 2},
#      {'is_overnight': False, 'start': '1100', 'end': '2230', 'day': 3},
#      {'is_overnight': False, 'start': '1100', 'end': '2230', 'day': 4},
#      {'is_overnight': False, 'start': '1130', 'end': '2230', 'day': 5}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': '',
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'tCkwBTuEFvhuaBoEUWqbuQ',
#   'alias': 'meli-cafe-and-juice-bar-chicago',
#   'name': 'Meli Cafe & Juice Bar',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tWtHOARci7HbaYIf224q5g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/meli-cafe-and-juice-bar-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 1038,
#   'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'wraps', 'title': 'Wraps'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.87761, 'longitude': -87.647},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '301 S Halsted St',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60661',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['301 S Halsted St', 'Chicago, IL 60661']},
#   'phone': '+13124540748',
#   'display_phone': '(312) 454-0748',
#   'distance': 172.2595534673058,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '0700',
#       'end': '1500',
#       'day': 0},
#      {'is_overnight': False, 'start': '0700', 'end': '1500', 'day': 1},
#      {'is_overnight': False, 'start': '0700', 'end': '1500', 'day': 2},
#      {'is_overnight': False, 'start': '0700', 'end': '1500', 'day': 3},
#      {'is_overnight': False, 'start': '0700', 'end': '1500', 'day': 4},
#      {'is_overnight': False, 'start': '0700', 'end': '1500', 'day': 5},
#      {'is_overnight': False, 'start': '0700', 'end': '1500', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': True}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': 'http://www.melicafe.com/',
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'XGeD1lflakOrRuHlOn4vhg',
#   'alias': 'rye-deli-and-drink-chicago',
#   'name': 'Rye Deli & Drink',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nl6mxmFAodhyNs2a308g8w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rye-deli-and-drink-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 97,
#   'categories': [{'alias': 'delis', 'title': 'Delis'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 41.88060499608243,
#    'longitude': -87.64655743829117},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '25 South Halsted St',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60661',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['25 South Halsted St', 'Chicago, IL 60661']},
#   'phone': '+13126022100',
#   'display_phone': '(312) 602-2100',
#   'distance': 145.5766477193354,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '0600',
#       'end': '2200',
#       'day': 0},
#      {'is_overnight': False, 'start': '0600', 'end': '2200', 'day': 1},
#      {'is_overnight': False, 'start': '0600', 'end': '2200', 'day': 2},
#      {'is_overnight': False, 'start': '0600', 'end': '2200', 'day': 3},
#      {'is_overnight': False, 'start': '0600', 'end': '2200', 'day': 4},
#      {'is_overnight': False, 'start': '0800', 'end': '1700', 'day': 5},
#      {'is_overnight': False, 'start': '0800', 'end': '1700', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': True}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': 'http://www.ryechicago.com/menu',
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': '0IqrRskWAowrfqPCJD3eQg',
#   'alias': 'xi-an-cuisine-chicago',
#   'name': 'Xi’an Cuisine',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Kj0JDoz3_RXJVptEPCRS9A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/xi-an-cuisine-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 109,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 41.877819, 'longitude': -87.646846},
#   'transactions': [],
#   'location': {'address1': '769 W Jackson Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60661',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['769 W Jackson Blvd', 'Chicago, IL 60661']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 188.34230802341477,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1100',
#       'end': '2130',
#       'day': 0},
#      {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 1},
#      {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 2},
#      {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 3},
#      {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 4},
#      {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 5},
#      {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': None,
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'dux6UvpMGJuHquFA3JfR3A',
#   'alias': 'green-street-smoked-meats-chicago',
#   'name': 'Green Street Smoked Meats',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vREgFglrHV6kxyDjp9fPLA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/green-street-smoked-meats-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 2172,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 41.88367058013238, 'longitude': -87.648907},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '112 N Green St',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['112 N Green St', 'Chicago, IL 60607']},
#   'phone': '+13127540431',
#   'display_phone': '(312) 754-0431',
#   'distance': 503.12827152964485,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1100',
#       'end': '2230',
#       'day': 0},
#      {'is_overnight': False, 'start': '1100', 'end': '2230', 'day': 1},
#      {'is_overnight': False, 'start': '1100', 'end': '2230', 'day': 2},
#      {'is_overnight': False, 'start': '1100', 'end': '2230', 'day': 3},
#      {'is_overnight': False, 'start': '1100', 'end': '2300', 'day': 4},
#      {'is_overnight': False, 'start': '1100', 'end': '2300', 'day': 5},
#      {'is_overnight': False, 'start': '1100', 'end': '2230', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': 'https://greenstreetmeats.com/menu/food-drink-menu/',
#    'open24_hours': None,
#    'waitlist_reservation': False}},
#  {'id': 'Vyl3bJeQ4beMqBTWhc9wQw',
#   'alias': 'citybird-chicago',
#   'name': 'CityBird',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/T808IH3vjyaPGoy8tStXXQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/citybird-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 55,
#   'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 41.879795, 'longitude': -87.647533},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '120 S Halsted St',
#    'address2': 'Ste D',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60661',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['120 S Halsted St', 'Ste D', 'Chicago, IL 60661']},
#   'phone': '+13122852882',
#   'display_phone': '(312) 285-2882',
#   'distance': 58.12968812345313,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1100',
#       'end': '2200',
#       'day': 0},
#      {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 1},
#      {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 2},
#      {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 3},
#      {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 4},
#      {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 5},
#      {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': 'https://www.citybirdtenders.com/menu/',
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': '1BHgaf25FpVSOXFpZF0pYw',
#   'alias': 'trivoli-tavern-chicago',
#   'name': 'Trivoli Tavern',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nfvmah3hLrSt6grMde5J8w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/trivoli-tavern-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 634,
#   'categories': [{'alias': 'tradamerican', 'title': 'American'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.8837221888722,
#    'longitude': -87.64903867652058},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '114 N Green St',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['114 N Green St', 'Chicago, IL 60607']},
#   'phone': '+13123662646',
#   'display_phone': '(312) 366-2646',
#   'distance': 511.95141213817806,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1600',
#       'end': '2200',
#       'day': 0},
#      {'is_overnight': False, 'start': '1600', 'end': '2200', 'day': 1},
#      {'is_overnight': False, 'start': '1600', 'end': '2200', 'day': 2},
#      {'is_overnight': False, 'start': '1600', 'end': '2200', 'day': 3},
#      {'is_overnight': False, 'start': '1600', 'end': '2230', 'day': 4},
#      {'is_overnight': False, 'start': '1030', 'end': '2230', 'day': 5},
#      {'is_overnight': False, 'start': '1030', 'end': '2200', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': 'https://trivolitavern.com/wp-content/uploads/TRV-Dinner-MobileMenu-11-04-22.pdf',
#    'open24_hours': None,
#    'waitlist_reservation': False}},
#  {'id': 'ytFpgrsKQ-RoWpBIB05OJw',
#   'alias': 'formentos-chicago',
#   'name': "Formento's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AmhTVJL6OoFbOG7aqak8aQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/formentos-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 817,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.88404, 'longitude': -87.65081},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '925 W Randolph St',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['925 W Randolph St', 'Chicago, IL 60607']},
#   'phone': '+13126907295',
#   'display_phone': '(312) 690-7295',
#   'distance': 605.4464687805746,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1630',
#       'end': '2100',
#       'day': 0},
#      {'is_overnight': False, 'start': '1630', 'end': '2100', 'day': 1},
#      {'is_overnight': False, 'start': '1630', 'end': '2100', 'day': 2},
#      {'is_overnight': False, 'start': '1630', 'end': '2100', 'day': 3},
#      {'is_overnight': False, 'start': '1630', 'end': '2200', 'day': 4},
#      {'is_overnight': False, 'start': '1000', 'end': '1430', 'day': 5},
#      {'is_overnight': False, 'start': '1630', 'end': '2200', 'day': 5},
#      {'is_overnight': False, 'start': '1000', 'end': '1430', 'day': 6},
#      {'is_overnight': False, 'start': '1630', 'end': '2100', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': 'http://www.formentos.com/menus/',
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'r732n4Oq1YO02K58fcR-Yg',
#   'alias': 'sushi-dokku-chicago-3',
#   'name': 'SUSHI DOKKU Japanese Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-7cXgTacMzonRFxWoyU-gA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sushi-dokku-chicago-3?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 645,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 41.88408424952515,
#    'longitude': -87.64846359794781},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '823 W Randolph St',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['823 W Randolph St', 'Chicago, IL 60607']},
#   'phone': '+13124558238',
#   'display_phone': '(312) 455-8238',
#   'distance': 538.1867977084376,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1600',
#       'end': '2100',
#       'day': 0},
#      {'is_overnight': False, 'start': '1600', 'end': '2200', 'day': 1},
#      {'is_overnight': False, 'start': '1600', 'end': '2200', 'day': 2},
#      {'is_overnight': False, 'start': '1600', 'end': '2200', 'day': 3},
#      {'is_overnight': False, 'start': '1200', 'end': '2300', 'day': 4},
#      {'is_overnight': False, 'start': '1600', 'end': '2300', 'day': 5},
#      {'is_overnight': False, 'start': '1600', 'end': '2100', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': 'https://www.sushidokku.com/sushi-kitchen-menu',
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': '65-YoAsiOo1-1jPQxvZsog',
#   'alias': 'el-che-steakhouse-and-bar-chicago',
#   'name': 'El Che Steakhouse & Bar',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0P2L_xpqNQAC8BqV0I7ATA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/el-che-steakhouse-and-bar-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 450,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 41.8829851, 'longitude': -87.6491649},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$$',
#   'location': {'address1': '845 W Washington Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['845 W Washington Blvd', 'Chicago, IL 60607']},
#   'phone': '+13122651130',
#   'display_phone': '(312) 265-1130',
#   'distance': 427.0932156483176,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1700',
#       'end': '2200',
#       'day': 0},
#      {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 1},
#      {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 2},
#      {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 3},
#      {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 4},
#      {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 5},
#      {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': 'https://elchechicago.com/menus',
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'vb5hLPqsBEPmBsY-77Wl2g',
#   'alias': 'viaggio-ristorante-and-lounge-chicago',
#   'name': 'Viaggio Ristorante & Lounge',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GH7on865lwL8x3HGYmc4MQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/viaggio-ristorante-and-lounge-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 882,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 41.88146617619969,
#    'longitude': -87.65316184110442},
#   'transactions': ['pickup'],
#   'price': '$$$',
#   'location': {'address1': '1027 W Madison St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1027 W Madison St', 'Chicago, IL 60607']},
#   'phone': '+13128293333',
#   'display_phone': '(312) 829-3333',
#   'distance': 555.5113804171675,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1700',
#       'end': '2100',
#       'day': 0},
#      {'is_overnight': False, 'start': '1700', 'end': '2100', 'day': 1},
#      {'is_overnight': False, 'start': '1700', 'end': '2100', 'day': 2},
#      {'is_overnight': False, 'start': '1700', 'end': '2100', 'day': 3},
#      {'is_overnight': False, 'start': '1700', 'end': '2100', 'day': 4},
#      {'is_overnight': False, 'start': '1700', 'end': '2100', 'day': 5},
#      {'is_overnight': False, 'start': '1600', 'end': '2000', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': 'http://www.viaggiochicago.com/?page_id=24',
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'Nz7OSIHnWcsnno-zzXKO1g',
#   'alias': 'the-allis-chicago-3',
#   'name': 'The Allis',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EMr4QwisG8iRfdpJaBddMg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-allis-chicago-3?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 860,
#   'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#    {'alias': 'newamerican', 'title': 'New American'}],
#   'rating': 3.9,
#   'coordinates': {'latitude': 41.883773, 'longitude': -87.648281},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '113 - 125 N Green St',
#    'address2': 'Soho House Chicago',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['113 - 125 N Green St',
#     'Soho House Chicago',
#     'Chicago, IL 60607']},
#   'phone': '+13125218000',
#   'display_phone': '(312) 521-8000',
#   'distance': 501.8013023019356,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '0700',
#       'end': '2200',
#       'day': 0},
#      {'is_overnight': False, 'start': '0700', 'end': '2200', 'day': 1},
#      {'is_overnight': False, 'start': '0700', 'end': '2200', 'day': 2},
#      {'is_overnight': False, 'start': '0700', 'end': '2300', 'day': 3},
#      {'is_overnight': True, 'start': '0700', 'end': '0100', 'day': 4},
#      {'is_overnight': True, 'start': '0700', 'end': '0100', 'day': 5},
#      {'is_overnight': False, 'start': '0800', 'end': '1430', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': True}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': 'http://www.theallis.com/#menus',
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'V4mcn826Kf4HEsBHqZagQw',
#   'alias': 'zeus-restaurant-chicago-2',
#   'name': 'Zeus Restaurant',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ORUCv-agtzXt5KuBFd_w1A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/zeus-restaurant-chicago-2?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 274,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.1,
#   'coordinates': {'latitude': 41.87815, 'longitude': -87.64773},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '806 W Jackson Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['806 W Jackson Blvd', 'Chicago, IL 60607']},
#   'phone': '+13122588789',
#   'display_phone': '(312) 258-8789',
#   'distance': 145.95398703980607,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1100',
#       'end': '2200',
#       'day': 0},
#      {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 1},
#      {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 2},
#      {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 3},
#      {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 4},
#      {'is_overnight': False, 'start': '1200', 'end': '2200', 'day': 5},
#      {'is_overnight': False, 'start': '1200', 'end': '1900', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': 'http://www.zeusgyros.com/menu',
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': '34x6HdWQ8uTFp9rYaUIrUg',
#   'alias': 'tamashii-ramen-chicago',
#   'name': 'Tamashii Ramen',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PlOn39FROU9A-PNNhhI1AQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tamashii-ramen-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 74,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 4.1,
#   'coordinates': {'latitude': 41.87815, 'longitude': -87.6478},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '810 W Jackson Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['810 W Jackson Blvd', 'Chicago, IL 60607']},
#   'phone': '+13125263166',
#   'display_phone': '(312) 526-3166',
#   'distance': 144.326936268806,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1130',
#       'end': '2130',
#       'day': 0},
#      {'is_overnight': False, 'start': '1130', 'end': '2130', 'day': 1},
#      {'is_overnight': False, 'start': '1130', 'end': '2130', 'day': 2},
#      {'is_overnight': False, 'start': '1130', 'end': '2130', 'day': 3},
#      {'is_overnight': False, 'start': '1130', 'end': '2200', 'day': 4},
#      {'is_overnight': False, 'start': '1130', 'end': '2200', 'day': 5},
#      {'is_overnight': False, 'start': '1130', 'end': '2130', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': 'http://www.tamashiiramenchicago.com/menus',
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'TBoYnkPNFn9ASccYCYsJfw',
#   'alias': 'nancys-pizza-chicago-west-loop-chicago',
#   'name': "Nancy's Pizza Chicago - West Loop",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/R1ejnBQWBIkGu2e2gihL8Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nancys-pizza-chicago-west-loop-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 229,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 41.88330703961659,
#    'longitude': -87.65279760169538},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1000 W Washington Blvd',
#    'address2': None,
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1000 W Washington Blvd', 'Chicago, IL 60607']},
#   'phone': '+13127339920',
#   'display_phone': '(312) 733-9920',
#   'distance': 645.8591752924934,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1100',
#       'end': '2300',
#       'day': 0},
#      {'is_overnight': False, 'start': '1100', 'end': '2300', 'day': 1},
#      {'is_overnight': False, 'start': '1100', 'end': '2300', 'day': 2},
#      {'is_overnight': False, 'start': '1100', 'end': '2300', 'day': 3},
#      {'is_overnight': False, 'start': '1100', 'end': '0000', 'day': 4},
#      {'is_overnight': False, 'start': '0000', 'end': '0100', 'day': 5},
#      {'is_overnight': False, 'start': '1100', 'end': '0000', 'day': 5},
#      {'is_overnight': False, 'start': '0000', 'end': '0100', 'day': 6},
#      {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': None,
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'mPFMi734NXkvLFotygLrCA',
#   'alias': 'sepia-chicago',
#   'name': 'Sepia',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Nk17prnTV7s1w5MJHCFvsQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sepia-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 1348,
#   'categories': [{'alias': 'newamerican', 'title': 'New American'}],
#   'rating': 3.9,
#   'coordinates': {'latitude': 41.883933, 'longitude': -87.6424},
#   'transactions': ['pickup'],
#   'price': '$$$$',
#   'location': {'address1': '123 N Jefferson St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60661',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['123 N Jefferson St', 'Chicago, IL 60661']},
#   'phone': '+13124411920',
#   'display_phone': '(312) 441-1920',
#   'distance': 639.7405023983406,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1700',
#       'end': '2100',
#       'day': 0},
#      {'is_overnight': False, 'start': '1700', 'end': '2100', 'day': 1},
#      {'is_overnight': False, 'start': '1700', 'end': '2100', 'day': 2},
#      {'is_overnight': False, 'start': '1700', 'end': '2100', 'day': 3},
#      {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 4},
#      {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 5}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': 'http://www.sepiachicago.com/menu/',
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'ojGaIraebGNJpMogczEd5Q',
#   'alias': 'green-street-local-chicago-2',
#   'name': 'Green Street Local',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2djHtXc2twTzMpVW351L7g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/green-street-local-chicago-2?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 231,
#   'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'lounges', 'title': 'Lounges'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 3.8,
#   'coordinates': {'latitude': 41.8799929, 'longitude': -87.6486381},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '130 S Green St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['130 S Green St', 'Chicago, IL 60607']},
#   'phone': '+13122266565',
#   'display_phone': '(312) 226-6565',
#   'distance': 142.14308861812452,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1600',
#       'end': '2200',
#       'day': 0},
#      {'is_overnight': False, 'start': '1600', 'end': '2200', 'day': 1},
#      {'is_overnight': False, 'start': '1600', 'end': '2200', 'day': 2},
#      {'is_overnight': False, 'start': '1600', 'end': '2200', 'day': 3},
#      {'is_overnight': False, 'start': '1100', 'end': '2300', 'day': 4},
#      {'is_overnight': False, 'start': '1100', 'end': '2300', 'day': 5},
#      {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': None,
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'iK1KjPM8-BdNW2pFk5e7Iw',
#   'alias': 'suenos-x-soho-house-chicago',
#   'name': 'Suenos x Soho House',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/svaiI1RocpHjp8HJflOzXQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/suenos-x-soho-house-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 43,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 41.8837455, 'longitude': -87.6482824},
#   'transactions': [],
#   'location': {'address1': '113-125 N Green St',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['113-125 N Green St', 'Chicago, IL 60607']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 498.2347127077909,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1700',
#       'end': '2200',
#       'day': 1},
#      {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 2},
#      {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 3},
#      {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 4},
#      {'is_overnight': False, 'start': '1100', 'end': '1400', 'day': 5},
#      {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 5},
#      {'is_overnight': False, 'start': '1100', 'end': '1400', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': 'https://www.suenoschi.com/menu',
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'FMoNA-t4uxss2JA37ZNEJg',
#   'alias': 'high-five-ramen-chicago-4',
#   'name': 'High Five Ramen',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lHRBLC05pL-tVJuzRKBg7Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/high-five-ramen-chicago-4?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 1030,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.88370754212763, 'longitude': -87.6487662},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '112 N Green St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['112 N Green St', 'Chicago, IL 60607']},
#   'phone': '+13123441749',
#   'display_phone': '(312) 344-1749',
#   'distance': 503.6962898915922,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1600',
#       'end': '2230',
#       'day': 0},
#      {'is_overnight': False, 'start': '1600', 'end': '2230', 'day': 1},
#      {'is_overnight': False, 'start': '1600', 'end': '2230', 'day': 2},
#      {'is_overnight': False, 'start': '1600', 'end': '2230', 'day': 3},
#      {'is_overnight': False, 'start': '1600', 'end': '2300', 'day': 4},
#      {'is_overnight': False, 'start': '1600', 'end': '2300', 'day': 5},
#      {'is_overnight': False, 'start': '1600', 'end': '2230', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': None,
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': '09eEic9nbbSYMRizNfWrLQ',
#   'alias': 'primos-chicago-pizza-chicago',
#   'name': 'Primos Chicago Pizza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/OoxwYxB0SRB1Ydm1J2zlTQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/primos-chicago-pizza-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 204,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 3.8,
#   'coordinates': {'latitude': 41.876834739546, 'longitude': -87.6481967255665},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '816 W Van Buren St',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['816 W Van Buren St', 'Chicago, IL 60607']},
#   'phone': '+13122431052',
#   'display_phone': '(312) 243-1052',
#   'distance': 295.09052944172265,
#   'business_hours': [{'open': [{'is_overnight': True,
#       'start': '0730',
#       'end': '0200',
#       'day': 0},
#      {'is_overnight': True, 'start': '0730', 'end': '0200', 'day': 1},
#      {'is_overnight': True, 'start': '0730', 'end': '0200', 'day': 2},
#      {'is_overnight': True, 'start': '0730', 'end': '0200', 'day': 3},
#      {'is_overnight': True, 'start': '0730', 'end': '0200', 'day': 4},
#      {'is_overnight': True, 'start': '1700', 'end': '0200', 'day': 5}],
#     'hours_type': 'REGULAR',
#     'is_open_now': True}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': 'https://primoschicagopizzatogo.com/menu',
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': '0lpQxkQuKOBuV8pylAaQfQ',
#   'alias': 'spectrum-bar-and-grill-chicago',
#   'name': 'Spectrum Bar and Grill',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rCCznlf2z71ze0KwAMr_Gw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/spectrum-bar-and-grill-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 138,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'tradamerican', 'title': 'American'},
#    {'alias': 'greek', 'title': 'Greek'}],
#   'rating': 3.4,
#   'coordinates': {'latitude': 41.8782577514648,
#    'longitude': -87.6470336914062},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '233 S Halsted St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60661',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['233 S Halsted St', 'Chicago, IL 60661']},
#   'phone': '+13127150770',
#   'display_phone': '(312) 715-0770',
#   'distance': 124.133038487529,
#   'business_hours': [{'open': [{'is_overnight': True,
#       'start': '1700',
#       'end': '0400',
#       'day': 0},
#      {'is_overnight': True, 'start': '1700', 'end': '0400', 'day': 1},
#      {'is_overnight': True, 'start': '1700', 'end': '0400', 'day': 2},
#      {'is_overnight': True, 'start': '1700', 'end': '0400', 'day': 3},
#      {'is_overnight': True, 'start': '1700', 'end': '0400', 'day': 4},
#      {'is_overnight': True, 'start': '1700', 'end': '0500', 'day': 5},
#      {'is_overnight': True, 'start': '1700', 'end': '0400', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': 'https://spectrumbarandgrill.com/menu-2/',
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'EL7PGkZSjm_K1I96PAMoNA',
#   'alias': '9-muses-chicago',
#   'name': '9 Muses',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/khS_u5ikNdq0UQSR3bipVQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/9-muses-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 204,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 3.7,
#   'coordinates': {'latitude': 41.8777101, 'longitude': -87.6470951},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '315 S Halsted St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60661',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['315 S Halsted St', 'Chicago, IL 60661']},
#   'phone': '+13129029922',
#   'display_phone': '(312) 902-9922',
#   'distance': 215.0024531998414,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1100',
#       'end': '2230',
#       'day': 0},
#      {'is_overnight': False, 'start': '1100', 'end': '2230', 'day': 1},
#      {'is_overnight': False, 'start': '1100', 'end': '2230', 'day': 2},
#      {'is_overnight': False, 'start': '1100', 'end': '2230', 'day': 3},
#      {'is_overnight': False, 'start': '1100', 'end': '0000', 'day': 4},
#      {'is_overnight': False, 'start': '1200', 'end': '0000', 'day': 5},
#      {'is_overnight': False, 'start': '1200', 'end': '2230', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': '',
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': '2L0cobUly2HYZaMoJlT8vg',
#   'alias': 'booze-box-chicago-3',
#   'name': 'Booze Box',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WzvYCtqSJ8LbL8N5Fw-3Kg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/booze-box-chicago-3?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 196,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 41.8840982277936,
#    'longitude': -87.64846235544489},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '823 W Randolph',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['823 W Randolph', 'Chicago, IL 60607']},
#   'phone': '+13124558238',
#   'display_phone': '(312) 455-8238',
#   'distance': 539.6838022648077,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1700',
#       'end': '2200',
#       'day': 1},
#      {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 2},
#      {'is_overnight': False, 'start': '1700', 'end': '2300', 'day': 3},
#      {'is_overnight': False, 'start': '1700', 'end': '0000', 'day': 4},
#      {'is_overnight': False, 'start': '1700', 'end': '0000', 'day': 5}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': 'https://www.sushidokku.com/drinks',
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': '_CoQ7eTOpP3B-oGpip-Lpg',
#   'alias': 'omakase-yume-chicago-2',
#   'name': 'Omakase Yume',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0pvGLxt7TAeuVCIe3Zdu0w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/omakase-yume-chicago-2?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 163,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.8830608124328,
#    'longitude': -87.6445323537732},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': '651 W Washington Blvd',
#    'address2': 'Ste 101',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60661',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['651 W Washington Blvd',
#     'Ste 101',
#     'Chicago, IL 60661']},
#   'phone': '+13122651610',
#   'display_phone': '(312) 265-1610',
#   'distance': 462.9204487138084,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1730',
#       'end': '1930',
#       'day': 0},
#      {'is_overnight': False, 'start': '1730', 'end': '2100', 'day': 1},
#      {'is_overnight': False, 'start': '1730', 'end': '2100', 'day': 2},
#      {'is_overnight': False, 'start': '1730', 'end': '2100', 'day': 3},
# ...
#     'hours_type': 'REGULAR',
#     'is_open_now': True}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': None,
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': '6qBfvpJHa-hCok7ML_Nbww',
#   'alias': 'el-foco-tacos-chicago',
#   'name': 'EL FOCO TACOS',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1XmRb2el7yqLGDR8CnsQKQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/el-foco-tacos-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 0,
#   'categories': [{'alias': 'foodstands', 'title': 'Food Stands'},
#    {'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 0.0,
#   'coordinates': {'latitude': 41.87497132249663,
#    'longitude': -87.65151276803229},
#   'transactions': [],
#   'location': {'address1': None,
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['Chicago, IL 60607']},
#   'phone': '+17086120442',
#   'display_phone': '(708) 612-0442',
#   'distance': 610.1389573981653,
#   'business_hours': [{'open': [{'is_overnight': True,
#       'start': '0000',
#       'end': '0000',
#       'day': 0},
#      {'is_overnight': True, 'start': '0000', 'end': '0000', 'day': 1},
#      {'is_overnight': True, 'start': '0000', 'end': '0000', 'day': 2},
#      {'is_overnight': True, 'start': '0000', 'end': '0000', 'day': 3},
#      {'is_overnight': True, 'start': '0000', 'end': '0000', 'day': 4},
#      {'is_overnight': True, 'start': '0000', 'end': '0000', 'day': 5},
#      {'is_overnight': True, 'start': '0000', 'end': '0000', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': True}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': None,
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'KxQsAanpMp0vBY7-wtkihg',
#   'alias': 'west-loop-sandwich-chicago',
#   'name': 'West Loop Sandwich',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/west-loop-sandwich-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 0,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 0.0,
#   'coordinates': {'latitude': 41.88192, 'longitude': -87.6471},
#   'transactions': [],
#   'location': {'address1': '1 N Halsted St',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60661',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1 N Halsted St', 'Chicago, IL 60661']},
#   'phone': '+13122078400',
#   'display_phone': '(312) 207-8400',
#   'distance': 440.360891157907,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1100',
#       'end': '1900',
#       'day': 0},
#      {'is_overnight': False, 'start': '1100', 'end': '1900', 'day': 1},
#      {'is_overnight': False, 'start': '1100', 'end': '1900', 'day': 2},
#      {'is_overnight': False, 'start': '1100', 'end': '1900', 'day': 3},
#      {'is_overnight': False, 'start': '1100', 'end': '1900', 'day': 4},
#      {'is_overnight': False, 'start': '1100', 'end': '1900', 'day': 5},
#      {'is_overnight': False, 'start': '1100', 'end': '1900', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': None,
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'VSMMO5R7SIiGf7DXWJ8jLQ',
#   'alias': 'chopped-salad-bar-chicago-2',
#   'name': 'Chopped Salad Bar',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chopped-salad-bar-chicago-2?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 0,
#   'categories': [{'alias': 'fooddeliveryservices',
#     'title': 'Food Delivery Services'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 0.0,
#   'coordinates': {'latitude': 41.883089738414704,
#    'longitude': -87.64400664147233},
#   'transactions': ['delivery'],
#   'location': {'address1': None,
#    'address2': None,
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60661',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['Chicago, IL 60661']},
#   'phone': '+17816060112',
#   'display_phone': '(781) 606-0112',
#   'distance': 487.0449084844091,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1100',
#       'end': '1630',
#       'day': 0},
#      {'is_overnight': False, 'start': '1100', 'end': '1630', 'day': 1},
#      {'is_overnight': False, 'start': '1100', 'end': '1630', 'day': 2},
#      {'is_overnight': False, 'start': '1100', 'end': '1630', 'day': 3},
#      {'is_overnight': False, 'start': '1100', 'end': '1630', 'day': 4}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': None,
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'ptrLzRLpq4dxuZ85EO3d_g',
#   'alias': 'kabob-city-chicago',
#   'name': 'Kabob City',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kabob-city-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 0,
#   'categories': [{'alias': 'fooddeliveryservices',
#     'title': 'Food Delivery Services'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'kebab', 'title': 'Kebab'}],
#   'rating': 0.0,
#   'coordinates': {'latitude': 41.87497132249663,
#    'longitude': -87.65151276803229},
#   'transactions': [],
#   'location': {'address1': None,
#    'address2': None,
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['Chicago, IL 60607']},
#   'phone': '+12245350029',
#   'display_phone': '(224) 535-0029',
#   'distance': 610.1389573981653,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1100',
#       'end': '2100',
#       'day': 0},
#      {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 1},
#      {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 2},
#      {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 3},
#      {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 4},
#      {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 5}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': None,
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'wWHJVwycJnH66kL6niLvfQ',
#   'alias': 'wing-run-chicago',
#   'name': 'Wing Run',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wing-run-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 0,
#   'categories': [{'alias': 'fooddeliveryservices',
#     'title': 'Food Delivery Services'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#   'rating': 0.0,
#   'coordinates': {'latitude': 41.87497132249663,
#    'longitude': -87.65151276803229},
#   'transactions': ['delivery'],
#   'location': {'address1': None,
#    'address2': None,
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['Chicago, IL 60607']},
#   'phone': '+13123748915',
#   'display_phone': '(312) 374-8915',
#   'distance': 610.1389573981653,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1700',
#       'end': '2300',
#       'day': 1},
#      {'is_overnight': False, 'start': '1700', 'end': '2300', 'day': 2},
#      {'is_overnight': False, 'start': '1700', 'end': '2300', 'day': 3},
#      {'is_overnight': False, 'start': '1700', 'end': '2300', 'day': 4},
#      {'is_overnight': False, 'start': '1700', 'end': '2300', 'day': 5},
#      {'is_overnight': False, 'start': '1100', 'end': '2300', 'day': 6}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': None,
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'GI2fptEERso1K3z0Z-lsxg',
#   'alias': 'chi-town-sandwich-chicago-2',
#   'name': 'Chi Town Sandwich',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chi-town-sandwich-chicago-2?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 0,
#   'categories': [{'alias': 'fooddeliveryservices',
#     'title': 'Food Delivery Services'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 0.0,
#   'coordinates': {'latitude': 41.883089738414704,
#    'longitude': -87.64400664147233},
#   'transactions': [],
#   'location': {'address1': None,
#    'address2': None,
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60661',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['Chicago, IL 60661']},
#   'phone': '+17816060112',
#   'display_phone': '(781) 606-0112',
#   'distance': 487.0449084844091,
#   'business_hours': [{'open': [{'is_overnight': False,
#       'start': '1100',
#       'end': '1630',
#       'day': 0},
#      {'is_overnight': False, 'start': '1100', 'end': '1630', 'day': 1},
#      {'is_overnight': False, 'start': '1100', 'end': '1630', 'day': 2},
#      {'is_overnight': False, 'start': '1100', 'end': '1630', 'day': 3},
#      {'is_overnight': False, 'start': '1100', 'end': '1630', 'day': 4}],
#     'hours_type': 'REGULAR',
#     'is_open_now': False}],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': None,
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'TifJXoWScGOQBrmjlqnaEQ',
#   'alias': 'le-peep-grill-chicago-2',
#   'name': 'Le Peep Grill',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/le-peep-grill-chicago-2?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 0,
#   'categories': [{'alias': 'tradamerican', 'title': 'American'}],
#   'rating': 0.0,
#   'coordinates': {'latitude': 41.88332, 'longitude': -87.652695},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '1000 W Washington Blvd',
#    'address2': None,
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1000 W Washington Blvd', 'Chicago, IL 60607']},
#   'phone': '+13125639990',
#   'display_phone': '(312) 563-9990',
#   'distance': 655.4500165466192,
#   'business_hours': [],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': None,
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'AcBRMPQOOzVCRnony0XC-Q',
#   'alias': 'spaketeria-chicago',
#   'name': 'Spaketeria',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/spaketeria-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 1,
#   'categories': [{'alias': 'restaurants', 'title': 'Restaurants'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 41.879009, 'longitude': -87.641964},
#   'transactions': [],
#   'location': {'address1': '565 W Adams',
#    'address2': 'Fl 3',
#    'address3': 'Illinois Institute Of Technology',
#    'city': 'Chicago',
#    'zip_code': '60661',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['565 W Adams',
#     'Fl 3',
#     'Illinois Institute Of Technology',
#     'Chicago, IL 60661']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 425.3353606313481,
#   'business_hours': [],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': None,
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'kJa0ObPhSofoyGOXZHvNSQ',
#   'alias': 'popeyes-famous-fried-chicken-chicago-25',
#   'name': "Popeye's Famous Fried Chicken",
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/popeyes-famous-fried-chicken-chicago-25?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 0,
#   'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#   'rating': 0.0,
#   'coordinates': {'latitude': 41.8802984, 'longitude': -87.6409248},
#   'transactions': [],
#   'location': {'address1': '113 S Clinton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60661',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['113 S Clinton St', 'Chicago, IL 60661']},
#   'phone': '+13124540055',
#   'display_phone': '(312) 454-0055',
#   'distance': 512.0194885009219,
#   'business_hours': [],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': None,
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'EOm5o61GP65JjrvQ2cVoIA',
#   'alias': 'halsted-street-deli-chicago-2',
#   'name': 'Halsted Street Deli',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/halsted-street-deli-chicago-2?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 0,
#   'categories': [{'alias': 'delis', 'title': 'Delis'}],
#   'rating': 0.0,
#   'coordinates': {'latitude': 41.8830994516611,
#    'longitude': -87.6513592153788},
#   'transactions': ['delivery'],
#   'location': {'address1': '954 W Washington Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60607',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['954 W Washington Blvd', 'Chicago, IL 60607']},
#   'phone': '+13124213354',
#   'display_phone': '(312) 421-3354',
#   'distance': 582.0562711916556,
#   'business_hours': [],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': None,
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': '6IzSYSwRuKgGPFpMQaebjg',
#   'alias': 'flik-international-chicago',
#   'name': 'Flik International',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/flik-international-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 1,
#   'categories': [{'alias': 'restaurants', 'title': 'Restaurants'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 41.882106, 'longitude': -87.641639},
#   'transactions': [],
#   'location': {'address1': '540 W Madison St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60661',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['540 W Madison St', 'Chicago, IL 60661']},
#   'phone': '+13124630118',
#   'display_phone': '(312) 463-0118',
#   'distance': 539.8945374008363,
#   'business_hours': [],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': None,
#    'open24_hours': None,
#    'waitlist_reservation': None}},
#  {'id': 'c6Yw5ftOqPf5nNmgNHNWJw',
#   'alias': 'sweet-corner-chicago',
#   'name': 'Sweet Corner',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sweet-corner-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#   'review_count': 0,
#   'categories': [{'alias': 'restaurants', 'title': 'Restaurants'}],
#   'rating': 0.0,
#   'coordinates': {'latitude': 41.8772621154785, 'longitude': -87.642936706543},
#   'transactions': [],
#   'location': {'address1': '328 S Jefferson St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60661',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['328 S Jefferson St', 'Chicago, IL 60661']},
#   'phone': '+13127150909',
#   'display_phone': '(312) 715-0909',
#   'distance': 439.2896055762011,
#   'business_hours': [],
#   'attributes': {'business_temp_closed': None,
#    'menu_url': None,
#    'open24_hours': None,
#    'waitlist_reservation': None}}]

# %%
def parse_api_response(data):
    """
    Parse Yelp API results to extract restaurant URLs.

    Args:
        data (string): String of properly formatted JSON.

    Returns:
        (list): list of URLs as strings from the input JSON.
    """

    data = json.loads(data)
    res_url=list(map(lambda x:x['url'], data['businesses']))
    return res_url

url, headers, url_params = location_search_params(api_key, "Bridgeport, Chicago, IL", offset=0)
response_text = requests.request('GET', url, headers=headers, params=url_params).text

parse_api_response(response_text)
# Out:
# ['https://www.yelp.com/biz/the-duck-inn-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#  'https://www.yelp.com/biz/francos-ristorante-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#  'https://www.yelp.com/biz/mins-noodle-house-%E6%B8%94%E5%AE%B6%E9%87%8D%E5%BA%86%E5%B0%8F%E9%9D%A2-chicago-32?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#  'https://www.yelp.com/biz/kimski-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#  'https://www.yelp.com/biz/stix-n-brix-pizza-chicago-2?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#  'https://www.yelp.com/biz/han-202-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#  'https://www.yelp.com/biz/shinya-ramen-house-chicago-3?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#  'https://www.yelp.com/biz/el-taco-azteca-bridgeport-chicago-2?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#  'https://www.yelp.com/biz/antique-taco-chicago-7?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#  'https://www.yelp.com/biz/taipei-cafe-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#  'https://www.yelp.com/biz/gios-cafe-and-deli-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#  'https://www.yelp.com/biz/georges-gyros-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#  'https://www.yelp.com/biz/pleasant-house-pub-chicago-3?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#  'https://www.yelp.com/biz/greek-prime-kitchen-and-bar-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#  'https://www.yelp.com/biz/bad-owl-coffee-roasters-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#  'https://www.yelp.com/biz/bridgeport-coffee-chicago-4?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#  'https://www.yelp.com/biz/qing-xiang-yuan-dumplings-chicago-3?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#  'https://www.yelp.com/biz/s-k-y-chicago-5?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#  'https://www.yelp.com/biz/qiao-lin-hotpot-chicago-chinatown-chicago?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w',
#  'https://www.yelp.com/biz/da-mao-jia-chicago-2?adjust_creative=JN4t62CTo5UGWhBoAuyd7w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JN4t62CTo5UGWhBoAuyd7w']

# %% [markdown]
# ## Working with Web Pages (and HTML)

# %%
url_lookup = {
"https://www.yelp.com/biz/the-jibarito-stop-chicago-2?start=225":"parse_page_test1.html",
"https://www.yelp.com/biz/the-jibarito-stop-chicago-2?start=245":"parse_page_test2.html"
}

def html_fetcher(url):
    """
    Return the raw HTML at the specified URL.
    Args:
        url (string):

    Returns:
        status_code (integer):
        raw_html (string): the raw HTML content of the response, properly encoded according to the HTTP headers.
    """
    html_file = url_lookup.get(url)
    with open(html_file, 'rb') as file:
        html_text = file.read()
        return 200, html_text


def parse_page(html):
    """
    Parse the reviews on a single page of a restaurant.

    Args:
        html (string): String of HTML corresponding to a Yelp restaurant

    Returns:
        tuple(list, string): a tuple of two elements
            first element: list of dictionaries corresponding to the extracted review information
            second element: URL for the next page of reviews (or None if it is the last page)
    """
    soup = BeautifulSoup(html,'html.parser')
    url_next = soup.find('link',rel='next')
    if url_next:
        url_next = url_next.get('href')
    else:
        url_next = None

    reviews = soup.find_all('div', itemprop="review")
    reviews_list = []
    for rev in reviews:
      author =rev.find('meta',itemprop='author')['content']
      rating =rev.find('meta',itemprop='ratingValue')['content']
      rating=float(rating)
      date =rev.find('meta',itemprop='datePublished')['content']
      description=rev.find('p',itemprop='description').text.strip()

      reviews_list.append({
          'author':author,
          'rating':rating,
          'date':date,
          'description':description
      })

    return reviews_list, url_next

code, html = html_fetcher("https://www.yelp.com/biz/the-jibarito-stop-chicago-2?start=225")
reviews_list, url_next = parse_page(html)
print(len(reviews_list)) # 20
print(url_next) #https://www.yelp.com/biz/the-jibarito-stop-chicago-2?start=245
# Out:
# 20
# https://www.yelp.com/biz/the-jibarito-stop-chicago-2?start=245

# %% [markdown]
# ###Extracting  all Yelp reviews for a Single Restaurant

# %%
def extract_reviews(url, html_fetcher):
    """
    Retrieve ALL of the reviews for a single restaurant on Yelp.

    Parameters:
        url (string): Yelp URL corresponding to the restaurant of interest.
        html_fetcher (function): A function that takes url and returns html status code and content

    Returns:
        reviews (list): list of dictionaries containing extracted review information
    """
    reviews = []

    cond = True
    while cond:
      code, html = html_fetcher(url)
      reviews_list, url_next = parse_page(html)
      reviews += reviews_list
      if url_next:
        url =url_next
      else:
        cond =False

    return reviews

# %% [markdown]
# You can test your function with this code:

# %%
data = extract_reviews('https://www.yelp.com/biz/the-jibarito-stop-chicago-2?start=225', html_fetcher=html_fetcher)
print(len(data))
print(data[0])
# Out:
# 35
# {'author': 'Jason S.', 'rating': 5.0, 'date': '2016-05-02', 'description': "This was one of my favorite food trucks but as of last fall they've opened a brick and mortar restaurant in the Pilsen neighborhood...the perfect success story of how a person can start out with a food truck and grow their business into a restaurant. The food is always delicious and the service is great!"}
